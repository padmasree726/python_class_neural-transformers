# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\kisho\Downloads\archive (2).zip")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0      country continent  population         day  \
# 0           0  Afghanistan      Asia  40754388.0  2025-07-28
# 1           1      Albania    Europe   2866374.0  2025-07-28
# 2           2      Algeria    Africa  45350148.0  2025-07-28
# 3           3      Andorra    Europe     77463.0  2025-07-28
# 4           4       Angola    Africa  35027343.0  2025-07-28
#
#                         time  active_cases  critical_cases  total_cases  \
# 0  2025-07-28 16:15:05+00:00       15098.0             NaN       234174
# 1  2025-07-28 16:15:05+00:00        1025.0             NaN       334863
# 2  2025-07-28 16:15:05+00:00       82068.0             NaN       272010
# 3  2025-07-28 16:15:06+00:00           NaN             NaN        48015
# 4  2025-07-28 16:15:06+00:00        1971.0             NaN       107327
#
#    recovered_cases  1M_pop_cases  1M_pop_deaths  total_deaths  1M_pop_tests  \
# 0         211080.0        5746.0          196.0        7996.0       34125.0
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0            country continent  population         day  \
# 226         226  Wallis-and-Futuna   Oceania     10982.0  2025-07-28
# 227         227     Western-Sahara    Africa    626161.0  2025-07-28
# 228         228              Yemen      Asia  31154867.0  2025-07-28
# 229         229             Zambia    Africa  19470234.0  2025-07-28
# 230         230           Zimbabwe    Africa  15331428.0  2025-07-28
#
#                           time  active_cases  critical_cases  total_cases  \
# 226  2025-07-28 16:15:08+00:00        3104.0             NaN         3550
# 227  2025-07-28 16:15:09+00:00           0.0             NaN           10
# 228  2025-07-28 16:15:08+00:00         662.0             NaN        11945
# 229  2025-07-28 16:15:05+00:00        3919.0             NaN       349304
# 230  2025-07-28 16:15:05+00:00        1731.0            12.0       266359
#
#      recovered_cases  1M_pop_cases  1M_pop_deaths  total_deaths  1M_pop_tests  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0              country      continent  population         day  \
# 0           0          Afghanistan           Asia  40754388.0  2025-07-28
# 1           1              Albania         Europe   2866374.0  2025-07-28
# 2           2              Algeria         Africa  45350148.0  2025-07-28
# 3           3              Andorra         Europe     77463.0  2025-07-28
# 4           4               Angola         Africa  35027343.0  2025-07-28
# 5           5             Anguilla  North-America     15230.0  2025-07-28
# 6           6  Antigua-and-Barbuda  North-America     99509.0  2025-07-28
# 7           7            Argentina  South-America  46010234.0  2025-07-28
# 8           8              Armenia           Asia   2971966.0  2025-07-28
# 9           9                Aruba  North-America    107609.0  2025-07-28
#
#                         time  active_cases  critical_cases  total_cases  \
# 0  2025-07-28 16:15:05+00:00       15098.0             NaN       234174
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'continent', 'population', 'day', 'time',
#        'active_cases', 'critical_cases', 'total_cases', 'recovered_cases',
#        '1M_pop_cases', '1M_pop_deaths', 'total_deaths', '1M_pop_tests',
#        'total_tests'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0    population  active_cases  critical_cases   total_cases  \
# count  231.000000  2.290000e+02  1.840000e+02       52.000000  2.310000e+02
# mean   115.000000  3.469404e+07  3.323757e+04       55.326923  3.050883e+06
# std     66.828138  1.386374e+08  1.654554e+05      142.919382  1.002125e+07
# min      0.000000  7.990000e+02  0.000000e+00        1.000000  9.000000e+00
# 25%     57.500000  4.454310e+05  2.875000e+01        3.750000  2.636600e+04
# 50%    115.000000  5.797805e+06  5.390000e+02       11.000000  2.068970e+05
# 75%    172.500000  2.210284e+07  5.842500e+03       24.250000  1.348198e+06
# max    230.000000  1.448471e+09  1.783377e+06      940.000000  1.118201e+08
#
#        recovered_cases   1M_pop_cases  1M_pop_deaths  total_deaths  \
# count     1.830000e+02     229.000000     224.000000  2.260000e+02
# mean      3.063211e+06  202950.253275    1277.348214  3.102071e+04
# std       1.024277e+07  206154.889634    1310.431844  1.103436e+05
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# country             object
# continent           object
# population         float64
# day                 object
# time                object
# active_cases       float64
# critical_cases     float64
# total_cases          int64
# recovered_cases    float64
# 1M_pop_cases       float64
# 1M_pop_deaths      float64
# total_deaths       float64
# 1M_pop_tests       float64
# total_tests        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# country              0
# continent            2
# population           2
# day                  0
# time                 0
# active_cases        47
# critical_cases     179
# total_cases          0
# recovered_cases     48
# 1M_pop_cases         2
# 1M_pop_deaths        7
# total_deaths         5
# 1M_pop_tests        18
# total_tests         18
# dtype: int64

# %%
data = {
    "name":["padma","priya","varshi"],
    "age":[21,22,23],
    "city":["chennai","erode","neyveli"]
}

# %%
type(data)
# Out:
# dict

# %%
df_1 = pd.DataFrame(data)

# %%
type(df_1)
# Out:
# pandas.core.frame.DataFrame

# %%
df_1
# Out:
#      name  age     city
# 0   padma   21  chennai
# 1   priya   22    erode
# 2  varshi   23  neyveli

# %%
df_1.head(1)
# Out:
#     name  age     city
# 0  padma   21  chennai

# %%
import pandas as pd

# %%
data_1 = {
    "a":10,
    "b":22,
    "c":30
}

# %%
df_2 = pd.Series(data_1)

# %%
df_2["a"]
# Out:
# np.int64(10)

# %%
df_1
# Out:
#      name  age     city
# 0   padma   21  chennai
# 1   priya   22    erode
# 2  varshi   23  neyveli

# %%
df_1["age"]
# Out:
# 0    21
# 1    22
# 2    23
# Name: age, dtype: int64
